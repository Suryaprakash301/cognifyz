# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
df=pd.read_csv("C:/Users/surya/Downloads/Dataset .csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# # Exlporing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # Handling Null values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df_mode=df['Cuisines'].mode()
df_mode
# Out:
# 0    North Indian
# Name: Cuisines, dtype: object

# %%
df['Cuisines'].fillna(df['Cuisines'].mode()[0], inplace=True)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# # Task-1

# %% [markdown]
# -->Analyze the text reviews to identify the most
# common positive and negative keywords.

# %%
df['Rating text'].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
words=df["Rating text"]
positive_keywords=["Very Good","Excellent","Good"]
negative_keywords=["Not rated","Poor","Average"]
positive_matches = words[words.isin(positive_keywords)]
negative_matches = words[words.isin(negative_keywords)]
positive_counts = positive_matches.mode()
negative_counts = negative_matches.mode()
print("Most Common Positive Review:")
print(positive_counts)
print("\nMost Common Negative Review:")
print(negative_counts)
# Out:
# Most Common Positive Review:
# 0    Good
# Name: Rating text, dtype: object
#
# Most Common Negative Review:
# 0    Average
# Name: Rating text, dtype: object

# %% [markdown]
# -->Calculate the average length of reviews and
# explore if there is a relationship between
# review length and rating.

# %%
df_analyze=df[['Rating text','Aggregate rating']].copy()
df_analyze['Review Length']=df_analyze['Rating text'].apply(lambda x: len(str(x)))
ave_rev_len=df_analyze.groupby('Aggregate rating')['Review Length'].mean()

# %%
plt.figure(figsize=(10,10))
ave_rev_len.plot(kind='bar',color='blue')
plt.title('Average Review Length For Each Rating Category')
plt.xlabel('Aggregate Rating')
plt.ylabel('Average review length character')
plt.show()

# %% [markdown]
# # Task-2

# %% [markdown]
# -->Identify the restaurants with the highest and
# lowest number of votes.

# %%
df.groupby('Restaurant Name')['Votes'].max().sort_values(ascending=False)
# Out:
# Restaurant Name
# Toit                         10934
# Truffles                      9667
# Hauz Khas Social              7931
# Peter Cat                     7574
# AB's - Absolute Barbecues     6907
#                              ...
# Laxmi Dairy                      0
# Delhi Foods                      0
# Annapurna Caterings              0
# Smily Cakes                      0
# Smoke Trailer Grill              0
# Name: Votes, Length: 7446, dtype: int64

# %%
df.groupby('Restaurant Name')['Votes'].min().sort_values(ascending=True).head(20)
# Out:
# Restaurant Name
# Laxmi Food Corner               0
# Healthy Nutrienty               0
# Costa Coffee                    0
# The Yolmo Kitchen               0
# Raju De Special Paneer Wale     0
# Soya Twist                      0
# Raju Fast Food                  0
# Shahi Hyderbadi Biryani         0
# Haryana Bhojnalaya              0
# Raju Ice Cream Parlor           0
# Shri Ram Dhaba                  0
# Raju Vaishno Amritsari Dhaba    0
# Ralhan Eating Corner            0
# Happy Italiano                  0
# Happy Hours                     0
# Shahi Chicken Point             0
# Hans's Planet-F                 0
# Ram Ram Ji Kachori Bhandar      0
# Rama Desi Ghee Meat Wala        0
# Bengali Restaurant              0
# Name: Votes, dtype: int64

# %% [markdown]
# --> Analyze if there is a correlation between the
# number of votes and the rating of
# restaurant

# %%
corr_df=df[['Votes','Aggregate rating']].corr()
corr_df
# Out:
#                      Votes  Aggregate rating
# Votes             1.000000          0.313691
# Aggregate rating  0.313691          1.000000

# %% [markdown]
# -->Analyze if there is a relationship between the
# price range and the availability of onlin
# delivery and table booking.

# %%
idf_analysis=df[['Price range','Has Online delivery','Has Table booking']].copy()
idf_analysis['Has Online delivery']=idf_analysis['Has Online delivery'].map({'Yes':True,'No':False})
idf_analysis['Has table booking']=idf_analysis['Has Table booking'].map({'Yes':True,'No':False})

# %%
relation_df=pd.pivot_table(idf_analysis,index='Price range',values=['Has Online delivery','Has table booking'],aggfunc=sum)
relation_df
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_13256\3742164658.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   relation_df=pd.pivot_table(idf_analysis,index='Price range',values=['Has Online delivery','Has table booking'],aggfunc=sum)
#              Has Online delivery  Has table booking
# Price range
# 1                            701                  1
# 2                           1286                239
# 3                            411                644
# 4                             53                274

# %% [markdown]
# -->Determine if higher-priced restaurants are more likely to offer these services

# %%
plt.figure(figsize=(10,8))
color=['blue','green']
relation_df.plot(kind='bar',stacked=True,color=color)
plt.title('Relationship between price Range and Availibility')
plt.xlabel('Price range')
plt.ylabel('Count')
plt.legend(title='Feature',loc='upper right')
plt.show()
